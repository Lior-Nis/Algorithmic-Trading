# %%
from LSTMTesting import LSTM

# %%
lstm = LSTM(5)
lstm.get_data('MSFT', '2022-03-04', '2023-03-04')
lstm.plot_stock()
# Out:
# [*********************100%***********************]  1 of 1 completed

# %%
lstm.split_data()
lstm.plot_split()

# %%
lstm.build_model()
lstm.train_model()
# Out:
# Metal device set to: Apple M2
#
# systemMemory: 8.00 GB
# maxCacheSize: 2.67 GB
# 2023-03-06 14:11:47.940556: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:306] Could not identify NUMA node of platform GPU ID 0, defaulting to 0. Your kernel may not have been built with NUMA support.
# 2023-03-06 14:11:47.940942: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:272] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 0 MB memory) -> physical PluggableDevice (device: 0, name: METAL, pci bus id: <undefined>)
# 2023-03-06 14:11:48.326160: W tensorflow/tsl/platform/profile_utils/cpu_utils.cc:128] Failed to get CPU frequency: 0 Hz
# 2023-03-06 14:11:48.860458: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# ...

# %%
lstm.plot_history()

# %%
lstm.predict()
lstm.rec_predict()
# Out:
# ...
# 1/1 [==============================] - 0s 25ms/step
# 2023-03-06 14:11:57.144746: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2023-03-06 14:11:57.181301: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# ...
# 1/1 [==============================] - 0s 10ms/step

# %%
lstm.plot_predictions(separate=1)

# %%
lstm.plot_predictions()

# %%
import numpy as np

dir_pred = np.rint(lstm.pred['test'])
dir_pred = np.where(dir_pred == 0, 1, dir_pred)

dir_real = np.rint(lstm.y['test'])

# %%
print(np.unique(dir_pred, return_counts=1), np.unique(dir_real))
# Out:
# (array([-1.,  1.], dtype=float32), array([ 9, 16])) [-1.  1.]

# %%
import matplotlib.pyplot as plt
from sklearn.datasets import make_classification
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay

cm = confusion_matrix(dir_real, dir_pred, labels=[-1, 1])
cm_display = ConfusionMatrixDisplay(cm).plot()
